# %%
# !pip install faker
# Out:
# ...
#   Obtaining dependency information for faker from https://files.pythonhosted.org/packages/cc/9a/74db0cf3115df2f71edcaf8d86ed556195ac31575212c20425820f81bfd0/Faker-20.1.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.7 MB 640.0 kB/s eta 0:00:03
#    - -------------------------------------- 0.1/1.7 MB 653.6 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.7 MB 726.2 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.7 MB 717.5 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.7 MB 655.4 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.7 MB 620.6 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.7 MB 591.4 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.7 MB 553.5 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.7 MB 553.5 kB/s eta 0:00:03
# ...

# %%
from faker import Faker
fake= Faker()
names = [fake.name().split() for i in range(100)]
# to normalize the date make sure that each list  in names must have only two elements
names = [name for name in names if len(name) == 2]
names
# Out:
# [['Jennifer', 'Stevenson'],
#  ['Katie', 'Montes'],
#  ['Brianna', 'Mercado'],
#  ['Sabrina', 'Brewer'],
#  ['Kimberly', 'Morgan'],
#  ['Dana', 'Ross'],
#  ['Joseph', 'Garcia'],
#  ['David', 'Krause'],
#  ['William', 'Key'],
#  ['Amanda', 'Lambert'],
#  ['Kimberly', 'Smith'],
#  ['Timothy', 'Gordon'],
#  ['Thomas', 'Torres'],
#  ['Jennifer', 'Garcia'],
#  ['Shawn', 'Rivera'],
#  ['Ruben', 'Martin'],
#  ['Daniel', 'Weaver'],
#  ['Ryan', 'Henderson'],
#  ['Casey', 'Kennedy'],
#  ['Miranda', 'Hawkins'],
#  ['Jack', 'Hart'],
#  ['Jessica', 'Garcia'],
#  ['George', 'Smith'],
#  ['Samantha', 'Gordon'],
#  ['Stephanie', 'Young'],
#  ['Michelle', 'Liu'],
#  ['Kristin', 'Miller'],
#  ['Tracy', 'Lambert'],
#  ['Crystal', 'Day'],
#  ['Philip', 'Charles'],
#  ['Gregory', 'Murphy'],
#  ['Linda', 'Reeves'],
#  ['Mary', 'Johnson'],
#  ['Craig', 'Herrera'],
#  ['Kristin', 'Blackburn'],
#  ['Joshua', 'Craig'],
#  ['Pamela', 'Baldwin'],
#  ['Robert', 'Chan'],
#  ['Melissa', 'Hall'],
# ...

# %%
import sqlite3
connection = sqlite3.connect("sample.db")

# %%
insert_query= 'INSERT into people(name , surname) VALUES (?,?)'

cursor = connection.cursor()

for name in names:
    cursor.execute(insert_query, name)

connection.commit()

# %%
select_query = 'SELECT * from people LIMIT 10'
for i in cursor.execute(select_query):
    print(i)
# Out:
# (1, 'Jennifer', 'Stevenson')
# (2, 'Katie', 'Montes')
# (3, 'Brianna', 'Mercado')
# (4, 'Sabrina', 'Brewer')
# (5, 'Kimberly', 'Morgan')
# (6, 'Dana', 'Ross')
# (7, 'Joseph', 'Garcia')
# (8, 'David', 'Krause')
# (9, 'William', 'Key')
# (10, 'Amanda', 'Lambert')
